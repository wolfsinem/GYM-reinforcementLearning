# %% [markdown]
# <a href="https://colab.research.google.com/github/wolfsinem/GYM-reinforcementLearning/blob/main/notebooks/week1/Reinforcement_Learning_project_Q_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reinforcement Learning project - Q-Learning

# %% [markdown]
# ### Preparation

# %% [markdown]
# Some dependencies need to be installed for the code to work. Furthermore, we will define some methods which allow us to show the OpenAI Gym renderings in this (headless) Google Colab environment.
#
# You only have to run these and don't need to change any of the code.

# %%
# Install dependencies
"""Note: if you are running this code on your own machine, you probably don't need all of these.
   Start with 'pip install gym' and install more packages if you run into errors."""
# !apt-get update > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg cmake > /dev/null 2>&1

# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# !pip install colabgymrender
# Out:
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.7/dist-packages (56.2.0)
# Requirement already satisfied: colabgymrender in /usr/local/lib/python3.7/dist-packages (1.0.8)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (0.2.3.5)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (2.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (5.5.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (4.1.2.30)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (2.4.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (1.19.5)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay->colabgymrender) (0.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (56.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (5.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->colabgymrender) (2.6.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender) (7.1.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->colabgymrender) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->colabgymrender) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->colabgymrender) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->colabgymrender) (1.15.0)

# %% [markdown]
# ### Imports for helper functions

# %%
import base64
import io
import math
from pathlib import Path

import gym
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
from colabgymrender.recorder import Recorder
from google.colab import drive
from gym.wrappers import Monitor
from IPython import display as ipythondisplay
from IPython.display import HTML
from pyvirtualdisplay import Display

# %%
# Mount your Google Drive. By doing so, you can store any output, models, videos, and images persistently.
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Create a directory to store the data for this lab. Feel free to change this.
data_path = Path('/content/gdrive/My Drive/Colab Notebooks/HU_RL/part1')
data_path.mkdir(parents=True, exist_ok=True)
video_path = data_path / 'video'

# %%
# Define helper functions to visually show what the models are doing.
# %matplotlib inline

gym.logger.set_level(gym.logger.ERROR)

display = Display(visible=0, size=(1400, 900))
display.start()

def show_video():
    # Display the stored video file
    # Credits: https://star-ai.github.io/Rendering-OpenAi-Gym-in-Colaboratory/
    mp4list = list(data_path.glob('video/*.mp4'))
    if len(mp4list) > 0:
        mp4 = mp4list[-1]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
            </video>'''.format(encoded.decode('ascii'))))
    else: 
        print('Could not find video')


def record_episode(idx):
    # This determines which episodes to record.
    # Since the video rendering in the OpenAI Gym is a bit buggy, we simply override it and decide
    # whether or not to render inside of our training loop.
    return True

    
def video_env(env):
    # Wraps the environment to write its output to a video file
    env = Monitor(env, video_path, video_callable=record_episode, force=True)
    return env

# %% [markdown]
# ### Test the environment

# %%
"""We will use a basic OpenAI Gym examle: CartPole-v0.
In this example, we will try to balance a pole on a cart.
This is similar to kids (and.. grown-ups) trying to balance sticks on their hands.

Check out the OpenAI Gym documentation to learn more: https://gym.openai.com/docs/"""

# Create the desired environment
env = gym.make("CartPole-v0")

# Wrap the environment, to make sure we get to see a fancy video
env = video_env(env)

# Before you can use a Gym environment, it needs to be reset.
state = env.reset()

# Perform random actions untill we drop the stick. Just as an example.
done = False
while not done:
    env.render()
    # The action_space contains all possible actions we can take.
    random_action = env.action_space.sample() 

    # After each action, we end up in a new state and receive a reward.
    # When we drop the pole (more than 12 degrees), or balance it long enough (200 steps),
    # or drive off the screen, done is set to True.
    state, reward, done, info = env.step(random_action)

# Show the results!
env.close()
# show_video()
# Out:
# 'We will use a basic OpenAI Gym examle: CartPole-v0.\nIn this example, we will try to balance a pole on a cart.\nThis is similar to kids (and.. grown-ups) trying to balance sticks on their hands.\n\nCheck out the OpenAI Gym documentation to learn more: https://gym.openai.com/docs/'
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# Neat, it did something (randomly)! 

# In order to train the system, we will try to predict the reward a certain actions yields given the state of the system.
# But what is the state anyway?

# In this environment, the state represents the cart's position and velocity, and the pole's angle and velocity.

# Let's check out the current state
print(f'State array: {state}')
print(f'Cart position: {state[0]} (range: [-4.8, 4.8])')
print(f'Cart velocity: {state[1]} (range: [-inf, inf])')
print(f'Pole angle: {state[2]} (range: [-0.418, 0.418])')
print(f'Pole velocity: {state[3]} (range [-inf, inf])')

# You can find out the minimum and maximum possible observation values using:
print(f'Low observation space:', env.observation_space.low)
print(f'High observation space:', env.observation_space.low)
# Out:
# State array: [-0.06595657 -1.0341383   0.24015033  1.9491046 ]
# Cart position: -0.06595657322407936 (range: [-4.8, 4.8])
# Cart velocity: -1.034138304951036 (range: [-inf, inf])
# Pole angle: 0.24015032993331345 (range: [-0.418, 0.418])
# Pole velocity: 1.9491046034023012 (range [-inf, inf])
# Low observation space: [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# High observation space: [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]

# %% [markdown]
# ### Implement Q-Learning
#
# Implement Q-Learning and find suitable parameters to reach a 200 reward.

# %% [markdown]
# ### Define parameters - Fill in the dots

# %%
num_episodes = 1000
num_steps = 200

num_episodes_between_status_update = 500
num_episodes_between_videos = 5000

n_actions = env.action_space.n
n_states = env.observation_space.shape[0]

min_alpha = 0.1       #learning rate
min_epsilon = 0.1     #exploration rate
gamma = 1          #discount factor

# %% [markdown]
# ### Q-Table creation

# %%
# Define the initial Q table as a random uniform distribution
buckets = (1,1,6,12)

upper_bounds = [env.observation_space.high[0], 0.5, env.observation_space.high[2], math.radians(50)]
lower_bounds = [env.observation_space.low[0], -0.5, env.observation_space.low[2], -math.radians(50)]

Q = np.zeros(buckets + (n_actions,)) 
print('Initial Q table:', Q.shape)
# Out:
# Initial Q table: (1, 1, 6, 12, 2)

# %% [markdown]
# ### Train

# %%
# functions
def discretize_state(state):
    """
    A Q-table cannot practically handle infinite states, so limit the state space by
    discretizing the state into buckets.
    """
    ratios = [(state[i] + abs(lower_bounds[i])) / (upper_bounds[i] - lower_bounds[i]) for i in range(len(state))]
    discrete_state = [int(round((buckets[i] - 1) * ratios[i])) for i in range(len(state))]
    discrete_state = [min(buckets[i] - 1, max(0, discrete_state[i])) for i in range(len(state))]
    return tuple(discrete_state)

def take_action(state, epsilon):
    """
    Take an action to either explore or exploit based on epsilon
    """
    if (np.random.random() < epsilon):
        action = env.action_space.sample()
    else:
        action = np.argmax(Q[state])
    return action

def estimated_max_for_next_state(new_state):
    """
    What's the best expected Q-value for the next state?
    """
    return np.argmax(Q[new_state])

def new_q_value(state, action, reward, new_state, alpha):
    """
    Calculate the new Q-value
    """
    Q[state][action] += min_alpha * (reward + gamma * np.max(Q[new_state]) - Q[state][action])
  
def get_epsilon(episode):
    """
    Decrease the exploration rate at each episode
    """
    return max(min_epsilon, min(1, 1.0 - math.log10((episode + 1) / 25)))

def get_alpha(episode):
    """
    Decrease the learning rate at each episode
    """
    return max(min_alpha, min(1.0, 1.0 - math.log10((episode + 1) / 25)))

# %%
# Time to train the system
rewards = [] 

for episode in range(num_episodes):
    current_state = env.reset() # Don't forget to reset the environment between episodes
    current_state = discretize_state(current_state)

    alpha = get_alpha(episode)
    epsilon = get_epsilon(episode)

    reward_sum = 0

    for t in range(num_steps):
        action = take_action(current_state, epsilon)
        new_state, reward, done, _ = env.step(action)
        new_state = discretize_state(new_state)

        new_q_value(current_state, action, reward, new_state, alpha)
        current_state = new_state

        reward_sum += reward

        # at the end of the episode
        if done:
            print(f'Total reward at episode {episode + 1}: {reward_sum}')
            break

    rewards.append(reward_sum)
print(f'Average reward over {episode + 1} episodes: {round(sum(rewards)/len(rewards))}')
print(f'Reward of 200 appeared {rewards.count(200)} times in {episode + 1} episodes')
# Out:
# Total reward at episode 1: 52.0
# Total reward at episode 2: 28.0
# Total reward at episode 3: 30.0
# Total reward at episode 4: 28.0
# Total reward at episode 5: 12.0
# Total reward at episode 6: 9.0
# Total reward at episode 7: 24.0
# Total reward at episode 8: 31.0
# Total reward at episode 9: 36.0
# Total reward at episode 10: 21.0
# Total reward at episode 11: 9.0
# Total reward at episode 12: 48.0
# Total reward at episode 13: 24.0
# Total reward at episode 14: 14.0
# Total reward at episode 15: 67.0
# Total reward at episode 16: 47.0
# Total reward at episode 17: 27.0
# Total reward at episode 18: 39.0
# Total reward at episode 19: 11.0
# Total reward at episode 20: 14.0
# Total reward at episode 21: 34.0
# Total reward at episode 22: 22.0
# Total reward at episode 23: 13.0
# Total reward at episode 24: 29.0
# Total reward at episode 25: 28.0
# Total reward at episode 26: 20.0
# Total reward at episode 27: 16.0
# Total reward at episode 28: 15.0
# Total reward at episode 29: 70.0
# Total reward at episode 30: 12.0
# Total reward at episode 31: 38.0
# Total reward at episode 32: 20.0
# Total reward at episode 33: 15.0
# Total reward at episode 34: 22.0
# Total reward at episode 35: 12.0
# Total reward at episode 36: 21.0
# Total reward at episode 37: 12.0
# Total reward at episode 38: 20.0
# Total reward at episode 39: 21.0
# Total reward at episode 40: 16.0
# Total reward at episode 41: 15.0
# Total reward at episode 42: 28.0
# Total reward at episode 43: 18.0
# Total reward at episode 44: 9.0
# Total reward at episode 45: 13.0
# Total reward at episode 46: 14.0
# Total reward at episode 47: 20.0
# Total reward at episode 48: 26.0
# Total reward at episode 49: 17.0
# Total reward at episode 50: 21.0
# Total reward at episode 51: 18.0
# Total reward at episode 52: 11.0
# Total reward at episode 53: 24.0
# Total reward at episode 54: 12.0
# Total reward at episode 55: 11.0
# Total reward at episode 56: 29.0
# Total reward at episode 57: 21.0
# Total reward at episode 58: 13.0
# Total reward at episode 59: 23.0
# Total reward at episode 60: 42.0
# Total reward at episode 61: 44.0
# Total reward at episode 62: 10.0
# Total reward at episode 63: 14.0
# Total reward at episode 64: 17.0
# Total reward at episode 65: 35.0
# Total reward at episode 66: 20.0
# Total reward at episode 67: 37.0
# Total reward at episode 68: 14.0
# Total reward at episode 69: 8.0
# Total reward at episode 70: 16.0
# Total reward at episode 71: 12.0
# Total reward at episode 72: 14.0
# Total reward at episode 73: 34.0
# Total reward at episode 74: 16.0
# Total reward at episode 75: 21.0
# Total reward at episode 76: 20.0
# Total reward at episode 77: 11.0
# Total reward at episode 78: 20.0
# Total reward at episode 79: 9.0
# Total reward at episode 80: 13.0
# Total reward at episode 81: 11.0
# Total reward at episode 82: 15.0
# Total reward at episode 83: 14.0
# Total reward at episode 84: 12.0
# Total reward at episode 85: 35.0
# Total reward at episode 86: 36.0
# Total reward at episode 87: 8.0
# Total reward at episode 88: 13.0
# Total reward at episode 89: 14.0
# Total reward at episode 90: 13.0
# Total reward at episode 91: 27.0
# Total reward at episode 92: 9.0
# Total reward at episode 93: 15.0
# Total reward at episode 94: 34.0
# Total reward at episode 95: 16.0
# Total reward at episode 96: 9.0
# Total reward at episode 97: 57.0
# Total reward at episode 98: 16.0
# Total reward at episode 99: 10.0
# Total reward at episode 100: 16.0
# Total reward at episode 101: 10.0
# Total reward at episode 102: 40.0
# Total reward at episode 103: 11.0
# Total reward at episode 104: 21.0
# Total reward at episode 105: 44.0
# Total reward at episode 106: 58.0
# Total reward at episode 107: 10.0
# Total reward at episode 108: 22.0
# Total reward at episode 109: 14.0
# Total reward at episode 110: 10.0
# Total reward at episode 111: 18.0
# Total reward at episode 112: 14.0
# Total reward at episode 113: 42.0
# Total reward at episode 114: 38.0
# Total reward at episode 115: 18.0
# Total reward at episode 116: 15.0
# Total reward at episode 117: 11.0
# Total reward at episode 118: 19.0
# Total reward at episode 119: 31.0
# Total reward at episode 120: 23.0
# Total reward at episode 121: 34.0
# Total reward at episode 122: 16.0
# Total reward at episode 123: 11.0
# Total reward at episode 124: 62.0
# Total reward at episode 125: 9.0
# Total reward at episode 126: 10.0
# Total reward at episode 127: 13.0
# Total reward at episode 128: 32.0
# Total reward at episode 129: 25.0
# Total reward at episode 130: 20.0
# Total reward at episode 131: 40.0
# Total reward at episode 132: 11.0
# Total reward at episode 133: 27.0
# Total reward at episode 134: 15.0
# Total reward at episode 135: 34.0
# Total reward at episode 136: 15.0
# Total reward at episode 137: 24.0
# Total reward at episode 138: 14.0
# Total reward at episode 139: 29.0
# Total reward at episode 140: 10.0
# Total reward at episode 141: 20.0
# Total reward at episode 142: 13.0
# Total reward at episode 143: 11.0
# Total reward at episode 144: 16.0
# Total reward at episode 145: 15.0
# Total reward at episode 146: 40.0
# Total reward at episode 147: 21.0
# Total reward at episode 148: 9.0
# Total reward at episode 149: 39.0
# Total reward at episode 150: 36.0
# Total reward at episode 151: 18.0
# Total reward at episode 152: 38.0
# Total reward at episode 153: 20.0
# Total reward at episode 154: 11.0
# Total reward at episode 155: 14.0
# Total reward at episode 156: 12.0
# Total reward at episode 157: 9.0
# Total reward at episode 158: 11.0
# Total reward at episode 159: 18.0
# Total reward at episode 160: 45.0
# Total reward at episode 161: 27.0
# Total reward at episode 162: 17.0
# Total reward at episode 163: 74.0
# Total reward at episode 164: 22.0
# Total reward at episode 165: 19.0
# Total reward at episode 166: 9.0
# Total reward at episode 167: 9.0
# Total reward at episode 168: 24.0
# Total reward at episode 169: 35.0
# Total reward at episode 170: 46.0
# Total reward at episode 171: 13.0
# Total reward at episode 172: 28.0
# Total reward at episode 173: 20.0
# Total reward at episode 174: 18.0
# Total reward at episode 175: 27.0
# Total reward at episode 176: 9.0
# Total reward at episode 177: 69.0
# Total reward at episode 178: 17.0
# Total reward at episode 179: 43.0
# Total reward at episode 180: 17.0
# Total reward at episode 181: 24.0
# Total reward at episode 182: 90.0
# Total reward at episode 183: 9.0
# Total reward at episode 184: 72.0
# Total reward at episode 185: 11.0
# Total reward at episode 186: 108.0
# Total reward at episode 187: 95.0
# Total reward at episode 188: 11.0
# Total reward at episode 189: 10.0
# Total reward at episode 190: 9.0
# Total reward at episode 191: 155.0
# Total reward at episode 192: 12.0
# Total reward at episode 193: 36.0
# Total reward at episode 194: 24.0
# Total reward at episode 195: 9.0
# Total reward at episode 196: 28.0
# Total reward at episode 197: 9.0
# Total reward at episode 198: 30.0
# Total reward at episode 199: 10.0
# Total reward at episode 200: 72.0
# Total reward at episode 201: 26.0
# Total reward at episode 202: 17.0
# Total reward at episode 203: 8.0
# Total reward at episode 204: 9.0
# Total reward at episode 205: 78.0
# Total reward at episode 206: 9.0
# Total reward at episode 207: 8.0
# Total reward at episode 208: 52.0
# Total reward at episode 209: 23.0
# Total reward at episode 210: 32.0
# Total reward at episode 211: 8.0
# Total reward at episode 212: 15.0
# Total reward at episode 213: 14.0
# Total reward at episode 214: 150.0
# Total reward at episode 215: 9.0
# Total reward at episode 216: 29.0
# Total reward at episode 217: 144.0
# Total reward at episode 218: 9.0
# Total reward at episode 219: 57.0
# Total reward at episode 220: 13.0
# Total reward at episode 221: 48.0
# Total reward at episode 222: 22.0
# Total reward at episode 223: 23.0
# Total reward at episode 224: 11.0
# Total reward at episode 225: 11.0
# Total reward at episode 226: 9.0
# Total reward at episode 227: 94.0
# Total reward at episode 228: 29.0
# Total reward at episode 229: 9.0
# Total reward at episode 230: 15.0
# Total reward at episode 231: 48.0
# Total reward at episode 232: 21.0
# Total reward at episode 233: 15.0
# Total reward at episode 234: 13.0
# Total reward at episode 235: 130.0
# Total reward at episode 236: 19.0
# Total reward at episode 237: 20.0
# Total reward at episode 238: 25.0
# Total reward at episode 239: 9.0
# Total reward at episode 240: 11.0
# Total reward at episode 241: 63.0
# Total reward at episode 242: 22.0
# Total reward at episode 243: 9.0
# Total reward at episode 244: 33.0
# Total reward at episode 245: 16.0
# Total reward at episode 246: 20.0
# Total reward at episode 247: 66.0
# Total reward at episode 248: 12.0
# Total reward at episode 249: 145.0
# Total reward at episode 250: 54.0
# Total reward at episode 251: 24.0
# Total reward at episode 252: 13.0
# Total reward at episode 253: 62.0
# Total reward at episode 254: 188.0
# Total reward at episode 255: 28.0
# Total reward at episode 256: 9.0
# Total reward at episode 257: 12.0
# Total reward at episode 258: 8.0
# Total reward at episode 259: 25.0
# Total reward at episode 260: 136.0
# Total reward at episode 261: 9.0
# Total reward at episode 262: 23.0
# Total reward at episode 263: 11.0
# Total reward at episode 264: 17.0
# Total reward at episode 265: 184.0
# Total reward at episode 266: 18.0
# Total reward at episode 267: 23.0
# Total reward at episode 268: 26.0
# Total reward at episode 269: 78.0
# Total reward at episode 270: 9.0
# Total reward at episode 271: 9.0
# Total reward at episode 272: 9.0
# Total reward at episode 273: 9.0
# Total reward at episode 274: 15.0
# Total reward at episode 275: 11.0
# Total reward at episode 276: 9.0
# Total reward at episode 277: 22.0
# Total reward at episode 278: 152.0
# Total reward at episode 279: 157.0
# Total reward at episode 280: 147.0
# Total reward at episode 281: 200.0
# Total reward at episode 282: 155.0
# Total reward at episode 283: 58.0
# Total reward at episode 284: 9.0
# Total reward at episode 285: 180.0
# Total reward at episode 286: 16.0
# Total reward at episode 287: 14.0
# Total reward at episode 288: 20.0
# Total reward at episode 289: 69.0
# Total reward at episode 290: 9.0
# Total reward at episode 291: 154.0
# Total reward at episode 292: 27.0
# Total reward at episode 293: 9.0
# Total reward at episode 294: 126.0
# Total reward at episode 295: 9.0
# Total reward at episode 296: 40.0
# Total reward at episode 297: 15.0
# Total reward at episode 298: 196.0
# Total reward at episode 299: 22.0
# Total reward at episode 300: 177.0
# Total reward at episode 301: 11.0
# Total reward at episode 302: 25.0
# Total reward at episode 303: 200.0
# Total reward at episode 304: 80.0
# Total reward at episode 305: 36.0
# Total reward at episode 306: 152.0
# Total reward at episode 307: 10.0
# Total reward at episode 308: 200.0
# Total reward at episode 309: 22.0
# Total reward at episode 310: 79.0
# Total reward at episode 311: 48.0
# Total reward at episode 312: 10.0
# Total reward at episode 313: 10.0
# Total reward at episode 314: 13.0
# Total reward at episode 315: 127.0
# Total reward at episode 316: 122.0
# Total reward at episode 317: 154.0
# Total reward at episode 318: 24.0
# Total reward at episode 319: 75.0
# Total reward at episode 320: 176.0
# Total reward at episode 321: 39.0
# Total reward at episode 322: 200.0
# Total reward at episode 323: 29.0
# Total reward at episode 324: 200.0
# Total reward at episode 325: 151.0
# Total reward at episode 326: 43.0
# Total reward at episode 327: 97.0
# Total reward at episode 328: 169.0
# Total reward at episode 329: 18.0
# Total reward at episode 330: 97.0
# Total reward at episode 331: 27.0
# Total reward at episode 332: 59.0
# Total reward at episode 333: 200.0
# Total reward at episode 334: 27.0
# Total reward at episode 335: 57.0
# Total reward at episode 336: 43.0
# Total reward at episode 337: 19.0
# Total reward at episode 338: 183.0
# Total reward at episode 339: 180.0
# Total reward at episode 340: 18.0
# Total reward at episode 341: 154.0
# Total reward at episode 342: 178.0
# Total reward at episode 343: 194.0
# Total reward at episode 344: 42.0
# Total reward at episode 345: 17.0
# Total reward at episode 346: 97.0
# Total reward at episode 347: 200.0
# Total reward at episode 348: 162.0
# Total reward at episode 349: 53.0
# Total reward at episode 350: 200.0
# Total reward at episode 351: 19.0
# Total reward at episode 352: 75.0
# Total reward at episode 353: 13.0
# Total reward at episode 354: 15.0
# Total reward at episode 355: 177.0
# Total reward at episode 356: 15.0
# Total reward at episode 357: 132.0
# Total reward at episode 358: 39.0
# Total reward at episode 359: 86.0
# Total reward at episode 360: 153.0
# Total reward at episode 361: 66.0
# Total reward at episode 362: 128.0
# Total reward at episode 363: 193.0
# Total reward at episode 364: 162.0
# Total reward at episode 365: 197.0
# Total reward at episode 366: 25.0
# Total reward at episode 367: 145.0
# Total reward at episode 368: 47.0
# Total reward at episode 369: 18.0
# Total reward at episode 370: 65.0
# Total reward at episode 371: 78.0
# Total reward at episode 372: 101.0
# Total reward at episode 373: 39.0
# Total reward at episode 374: 59.0
# Total reward at episode 375: 132.0
# Total reward at episode 376: 108.0
# Total reward at episode 377: 154.0
# Total reward at episode 378: 46.0
# Total reward at episode 379: 154.0
# Total reward at episode 380: 125.0
# Total reward at episode 381: 28.0
# Total reward at episode 382: 95.0
# Total reward at episode 383: 149.0
# Total reward at episode 384: 31.0
# Total reward at episode 385: 184.0
# Total reward at episode 386: 147.0
# Total reward at episode 387: 13.0
# Total reward at episode 388: 139.0
# Total reward at episode 389: 98.0
# Total reward at episode 390: 153.0
# Total reward at episode 391: 172.0
# Total reward at episode 392: 200.0
# Total reward at episode 393: 200.0
# Total reward at episode 394: 115.0
# Total reward at episode 395: 200.0
# Total reward at episode 396: 179.0
# Total reward at episode 397: 67.0
# Total reward at episode 398: 125.0
# Total reward at episode 399: 200.0
# Total reward at episode 400: 133.0
# Total reward at episode 401: 199.0
# Total reward at episode 402: 185.0
# Total reward at episode 403: 93.0
# Total reward at episode 404: 156.0
# Total reward at episode 405: 179.0
# Total reward at episode 406: 104.0
# Total reward at episode 407: 161.0
# Total reward at episode 408: 200.0
# Total reward at episode 409: 200.0
# Total reward at episode 410: 124.0
# Total reward at episode 411: 179.0
# Total reward at episode 412: 161.0
# Total reward at episode 413: 133.0
# Total reward at episode 414: 194.0
# Total reward at episode 415: 73.0
# Total reward at episode 416: 182.0
# Total reward at episode 417: 171.0
# Total reward at episode 418: 169.0
# Total reward at episode 419: 141.0
# Total reward at episode 420: 194.0
# Total reward at episode 421: 200.0
# Total reward at episode 422: 184.0
# Total reward at episode 423: 87.0
# Total reward at episode 424: 146.0
# Total reward at episode 425: 200.0
# Total reward at episode 426: 55.0
# Total reward at episode 427: 176.0
# Total reward at episode 428: 200.0
# Total reward at episode 429: 197.0
# Total reward at episode 430: 153.0
# Total reward at episode 431: 168.0
# Total reward at episode 432: 200.0
# Total reward at episode 433: 200.0
# Total reward at episode 434: 92.0
# Total reward at episode 435: 132.0
# Total reward at episode 436: 178.0
# Total reward at episode 437: 170.0
# Total reward at episode 438: 200.0
# Total reward at episode 439: 147.0
# Total reward at episode 440: 152.0
# Total reward at episode 441: 200.0
# Total reward at episode 442: 163.0
# Total reward at episode 443: 200.0
# Total reward at episode 444: 30.0
# Total reward at episode 445: 142.0
# Total reward at episode 446: 151.0
# Total reward at episode 447: 90.0
# Total reward at episode 448: 200.0
# Total reward at episode 449: 175.0
# Total reward at episode 450: 200.0
# Total reward at episode 451: 200.0
# Total reward at episode 452: 161.0
# Total reward at episode 453: 148.0
# Total reward at episode 454: 186.0
# Total reward at episode 455: 200.0
# Total reward at episode 456: 200.0
# Total reward at episode 457: 173.0
# Total reward at episode 458: 9.0
# Total reward at episode 459: 132.0
# Total reward at episode 460: 200.0
# Total reward at episode 461: 188.0
# Total reward at episode 462: 200.0
# Total reward at episode 463: 19.0
# Total reward at episode 464: 149.0
# Total reward at episode 465: 149.0
# Total reward at episode 466: 137.0
# Total reward at episode 467: 128.0
# Total reward at episode 468: 134.0
# Total reward at episode 469: 200.0
# Total reward at episode 470: 200.0
# Total reward at episode 471: 153.0
# Total reward at episode 472: 200.0
# Total reward at episode 473: 200.0
# Total reward at episode 474: 175.0
# Total reward at episode 475: 200.0
# Total reward at episode 476: 200.0
# Total reward at episode 477: 200.0
# Total reward at episode 478: 166.0
# Total reward at episode 479: 148.0
# Total reward at episode 480: 200.0
# Total reward at episode 481: 192.0
# Total reward at episode 482: 15.0
# Total reward at episode 483: 126.0
# Total reward at episode 484: 200.0
# Total reward at episode 485: 102.0
# Total reward at episode 486: 176.0
# Total reward at episode 487: 200.0
# Total reward at episode 488: 187.0
# Total reward at episode 489: 200.0
# Total reward at episode 490: 38.0
# Total reward at episode 491: 99.0
# Total reward at episode 492: 200.0
# Total reward at episode 493: 141.0
# Total reward at episode 494: 141.0
# Total reward at episode 495: 191.0
# Total reward at episode 496: 185.0
# Total reward at episode 497: 9.0
# Total reward at episode 498: 120.0
# Total reward at episode 499: 180.0
# Total reward at episode 500: 34.0
# Total reward at episode 501: 119.0
# Total reward at episode 502: 172.0
# Total reward at episode 503: 152.0
# Total reward at episode 504: 200.0
# Total reward at episode 505: 147.0
# Total reward at episode 506: 200.0
# Total reward at episode 507: 200.0
# Total reward at episode 508: 127.0
# Total reward at episode 509: 154.0
# Total reward at episode 510: 200.0
# Total reward at episode 511: 53.0
# Total reward at episode 512: 200.0
# Total reward at episode 513: 200.0
# Total reward at episode 514: 190.0
# Total reward at episode 515: 200.0
# Total reward at episode 516: 200.0
# Total reward at episode 517: 200.0
# Total reward at episode 518: 138.0
# Total reward at episode 519: 78.0
# Total reward at episode 520: 200.0
# Total reward at episode 521: 200.0
# Total reward at episode 522: 200.0
# Total reward at episode 523: 66.0
# Total reward at episode 524: 178.0
# Total reward at episode 525: 200.0
# Total reward at episode 526: 184.0
# Total reward at episode 527: 200.0
# Total reward at episode 528: 125.0
# Total reward at episode 529: 200.0
# Total reward at episode 530: 200.0
# Total reward at episode 531: 200.0
# Total reward at episode 532: 85.0
# Total reward at episode 533: 200.0
# Total reward at episode 534: 13.0
# Total reward at episode 535: 200.0
# Total reward at episode 536: 200.0
# Total reward at episode 537: 172.0
# Total reward at episode 538: 143.0
# Total reward at episode 539: 200.0
# Total reward at episode 540: 188.0
# Total reward at episode 541: 200.0
# Total reward at episode 542: 200.0
# Total reward at episode 543: 200.0
# Total reward at episode 544: 163.0
# Total reward at episode 545: 200.0
# Total reward at episode 546: 170.0
# Total reward at episode 547: 200.0
# Total reward at episode 548: 140.0
# Total reward at episode 549: 200.0
# Total reward at episode 550: 14.0
# Total reward at episode 551: 200.0
# Total reward at episode 552: 200.0
# Total reward at episode 553: 195.0
# Total reward at episode 554: 200.0
# Total reward at episode 555: 23.0
# Total reward at episode 556: 23.0
# Total reward at episode 557: 187.0
# Total reward at episode 558: 200.0
# Total reward at episode 559: 10.0
# Total reward at episode 560: 200.0
# Total reward at episode 561: 148.0
# Total reward at episode 562: 200.0
# Total reward at episode 563: 189.0
# Total reward at episode 564: 158.0
# Total reward at episode 565: 200.0
# Total reward at episode 566: 152.0
# Total reward at episode 567: 138.0
# Total reward at episode 568: 62.0
# Total reward at episode 569: 200.0
# Total reward at episode 570: 66.0
# Total reward at episode 571: 200.0
# Total reward at episode 572: 200.0
# Total reward at episode 573: 200.0
# Total reward at episode 574: 200.0
# Total reward at episode 575: 184.0
# Total reward at episode 576: 200.0
# Total reward at episode 577: 11.0
# Total reward at episode 578: 200.0
# Total reward at episode 579: 197.0
# Total reward at episode 580: 188.0
# Total reward at episode 581: 199.0
# Total reward at episode 582: 171.0
# Total reward at episode 583: 171.0
# Total reward at episode 584: 200.0
# Total reward at episode 585: 11.0
# Total reward at episode 586: 196.0
# Total reward at episode 587: 200.0
# Total reward at episode 588: 200.0
# Total reward at episode 589: 197.0
# Total reward at episode 590: 200.0
# Total reward at episode 591: 49.0
# Total reward at episode 592: 200.0
# Total reward at episode 593: 200.0
# Total reward at episode 594: 200.0
# Total reward at episode 595: 200.0
# Total reward at episode 596: 179.0
# Total reward at episode 597: 167.0
# Total reward at episode 598: 42.0
# Total reward at episode 599: 50.0
# Total reward at episode 600: 200.0
# Total reward at episode 601: 200.0
# Total reward at episode 602: 200.0
# Total reward at episode 603: 200.0
# Total reward at episode 604: 200.0
# Total reward at episode 605: 136.0
# Total reward at episode 606: 170.0
# Total reward at episode 607: 11.0
# Total reward at episode 608: 129.0
# Total reward at episode 609: 200.0
# Total reward at episode 610: 23.0
# Total reward at episode 611: 200.0
# Total reward at episode 612: 35.0
# Total reward at episode 613: 144.0
# Total reward at episode 614: 200.0
# Total reward at episode 615: 200.0
# Total reward at episode 616: 180.0
# Total reward at episode 617: 200.0
# Total reward at episode 618: 200.0
# Total reward at episode 619: 200.0
# Total reward at episode 620: 200.0
# Total reward at episode 621: 50.0
# Total reward at episode 622: 132.0
# Total reward at episode 623: 177.0
# Total reward at episode 624: 188.0
# Total reward at episode 625: 159.0
# Total reward at episode 626: 200.0
# Total reward at episode 627: 200.0
# Total reward at episode 628: 189.0
# Total reward at episode 629: 195.0
# Total reward at episode 630: 200.0
# Total reward at episode 631: 200.0
# Total reward at episode 632: 200.0
# Total reward at episode 633: 200.0
# Total reward at episode 634: 137.0
# Total reward at episode 635: 153.0
# Total reward at episode 636: 200.0
# Total reward at episode 637: 200.0
# Total reward at episode 638: 183.0
# Total reward at episode 639: 154.0
# Total reward at episode 640: 200.0
# Total reward at episode 641: 200.0
# Total reward at episode 642: 200.0
# Total reward at episode 643: 200.0
# Total reward at episode 644: 120.0
# Total reward at episode 645: 53.0
# Total reward at episode 646: 193.0
# Total reward at episode 647: 62.0
# Total reward at episode 648: 200.0
# Total reward at episode 649: 147.0
# Total reward at episode 650: 200.0
# Total reward at episode 651: 200.0
# Total reward at episode 652: 200.0
# Total reward at episode 653: 192.0
# Total reward at episode 654: 200.0
# Total reward at episode 655: 125.0
# Total reward at episode 656: 172.0
# Total reward at episode 657: 200.0
# Total reward at episode 658: 200.0
# Total reward at episode 659: 200.0
# Total reward at episode 660: 164.0
# Total reward at episode 661: 186.0
# Total reward at episode 662: 196.0
# Total reward at episode 663: 84.0
# Total reward at episode 664: 200.0
# Total reward at episode 665: 171.0
# Total reward at episode 666: 94.0
# Total reward at episode 667: 82.0
# Total reward at episode 668: 158.0
# Total reward at episode 669: 33.0
# Total reward at episode 670: 75.0
# Total reward at episode 671: 29.0
# Total reward at episode 672: 130.0
# Total reward at episode 673: 17.0
# Total reward at episode 674: 128.0
# Total reward at episode 675: 94.0
# Total reward at episode 676: 192.0
# Total reward at episode 677: 200.0
# Total reward at episode 678: 177.0
# Total reward at episode 679: 200.0
# Total reward at episode 680: 200.0
# Total reward at episode 681: 200.0
# Total reward at episode 682: 200.0
# Total reward at episode 683: 200.0
# Total reward at episode 684: 200.0
# Total reward at episode 685: 200.0
# Total reward at episode 686: 200.0
# Total reward at episode 687: 200.0
# Total reward at episode 688: 27.0
# Total reward at episode 689: 132.0
# Total reward at episode 690: 200.0
# Total reward at episode 691: 200.0
# Total reward at episode 692: 200.0
# Total reward at episode 693: 154.0
# Total reward at episode 694: 200.0
# Total reward at episode 695: 200.0
# Total reward at episode 696: 200.0
# Total reward at episode 697: 200.0
# Total reward at episode 698: 200.0
# Total reward at episode 699: 200.0
# Total reward at episode 700: 200.0
# Total reward at episode 701: 200.0
# Total reward at episode 702: 200.0
# Total reward at episode 703: 200.0
# Total reward at episode 704: 200.0
# Total reward at episode 705: 200.0
# Total reward at episode 706: 200.0
# Total reward at episode 707: 200.0
# Total reward at episode 708: 200.0
# Total reward at episode 709: 200.0
# Total reward at episode 710: 200.0
# Total reward at episode 711: 200.0
# Total reward at episode 712: 200.0
# Total reward at episode 713: 200.0
# Total reward at episode 714: 200.0
# Total reward at episode 715: 200.0
# Total reward at episode 716: 200.0
# Total reward at episode 717: 200.0
# Total reward at episode 718: 200.0
# Total reward at episode 719: 200.0
# Total reward at episode 720: 200.0
# Total reward at episode 721: 200.0
# Total reward at episode 722: 200.0
# Total reward at episode 723: 200.0
# Total reward at episode 724: 200.0
# Total reward at episode 725: 200.0
# Total reward at episode 726: 200.0
# Total reward at episode 727: 200.0
# Total reward at episode 728: 200.0
# Total reward at episode 729: 200.0
# Total reward at episode 730: 200.0
# Total reward at episode 731: 200.0
# Total reward at episode 732: 200.0
# Total reward at episode 733: 200.0
# Total reward at episode 734: 200.0
# Total reward at episode 735: 200.0
# Total reward at episode 736: 200.0
# Total reward at episode 737: 200.0
# Total reward at episode 738: 200.0
# Total reward at episode 739: 200.0
# Total reward at episode 740: 165.0
# Total reward at episode 741: 200.0
# Total reward at episode 742: 200.0
# Total reward at episode 743: 200.0
# Total reward at episode 744: 200.0
# Total reward at episode 745: 200.0
# Total reward at episode 746: 200.0
# Total reward at episode 747: 200.0
# Total reward at episode 748: 200.0
# Total reward at episode 749: 200.0
# Total reward at episode 750: 200.0
# Total reward at episode 751: 200.0
# Total reward at episode 752: 200.0
# Total reward at episode 753: 200.0
# Total reward at episode 754: 200.0
# Total reward at episode 755: 200.0
# Total reward at episode 756: 200.0
# Total reward at episode 757: 200.0
# Total reward at episode 758: 200.0
# Total reward at episode 759: 200.0
# Total reward at episode 760: 200.0
# Total reward at episode 761: 200.0
# Total reward at episode 762: 200.0
# Total reward at episode 763: 200.0
# Total reward at episode 764: 200.0
# Total reward at episode 765: 200.0
# Total reward at episode 766: 200.0
# Total reward at episode 767: 200.0
# Total reward at episode 768: 200.0
# Total reward at episode 769: 200.0
# Total reward at episode 770: 200.0
# Total reward at episode 771: 200.0
# Total reward at episode 772: 200.0
# Total reward at episode 773: 200.0
# Total reward at episode 774: 200.0
# Total reward at episode 775: 200.0
# Total reward at episode 776: 200.0
# Total reward at episode 777: 200.0
# Total reward at episode 778: 200.0
# Total reward at episode 779: 200.0
# Total reward at episode 780: 200.0
# Total reward at episode 781: 200.0
# Total reward at episode 782: 200.0
# Total reward at episode 783: 200.0
# Total reward at episode 784: 200.0
# Total reward at episode 785: 200.0
# Total reward at episode 786: 200.0
# Total reward at episode 787: 200.0
# Total reward at episode 788: 200.0
# Total reward at episode 789: 200.0
# Total reward at episode 790: 200.0
# Total reward at episode 791: 200.0
# Total reward at episode 792: 200.0
# Total reward at episode 793: 200.0
# Total reward at episode 794: 200.0
# Total reward at episode 795: 200.0
# Total reward at episode 796: 200.0
# Total reward at episode 797: 200.0
# Total reward at episode 798: 200.0
# Total reward at episode 799: 200.0
# Total reward at episode 800: 200.0
# Total reward at episode 801: 200.0
# Total reward at episode 802: 200.0
# Total reward at episode 803: 144.0
# Total reward at episode 804: 200.0
# Total reward at episode 805: 200.0
# Total reward at episode 806: 200.0
# Total reward at episode 807: 200.0
# Total reward at episode 808: 200.0
# Total reward at episode 809: 200.0
# Total reward at episode 810: 200.0
# Total reward at episode 811: 200.0
# Total reward at episode 812: 200.0
# Total reward at episode 813: 200.0
# Total reward at episode 814: 200.0
# Total reward at episode 815: 200.0
# Total reward at episode 816: 200.0
# Total reward at episode 817: 200.0
# Total reward at episode 818: 200.0
# Total reward at episode 819: 200.0
# Total reward at episode 820: 200.0
# Total reward at episode 821: 200.0
# Total reward at episode 822: 200.0
# Total reward at episode 823: 200.0
# Total reward at episode 824: 200.0
# Total reward at episode 825: 200.0
# Total reward at episode 826: 200.0
# Total reward at episode 827: 200.0
# Total reward at episode 828: 200.0
# Total reward at episode 829: 200.0
# Total reward at episode 830: 200.0
# Total reward at episode 831: 200.0
# Total reward at episode 832: 200.0
# Total reward at episode 833: 200.0
# Total reward at episode 834: 200.0
# Total reward at episode 835: 200.0
# Total reward at episode 836: 200.0
# Total reward at episode 837: 200.0
# Total reward at episode 838: 200.0
# Total reward at episode 839: 200.0
# Total reward at episode 840: 200.0
# Total reward at episode 841: 200.0
# Total reward at episode 842: 200.0
# Total reward at episode 843: 200.0
# Total reward at episode 844: 200.0
# Total reward at episode 845: 200.0
# Total reward at episode 846: 200.0
# Total reward at episode 847: 200.0
# Total reward at episode 848: 200.0
# Total reward at episode 849: 200.0
# Total reward at episode 850: 200.0
# Total reward at episode 851: 200.0
# Total reward at episode 852: 200.0
# Total reward at episode 853: 200.0
# Total reward at episode 854: 200.0
# Total reward at episode 855: 200.0
# Total reward at episode 856: 200.0
# Total reward at episode 857: 200.0
# Total reward at episode 858: 200.0
# Total reward at episode 859: 200.0
# Total reward at episode 860: 200.0
# Total reward at episode 861: 200.0
# Total reward at episode 862: 200.0
# Total reward at episode 863: 200.0
# Total reward at episode 864: 200.0
# Total reward at episode 865: 200.0
# Total reward at episode 866: 200.0
# Total reward at episode 867: 200.0
# Total reward at episode 868: 200.0
# Total reward at episode 869: 200.0
# Total reward at episode 870: 200.0
# Total reward at episode 871: 153.0
# Total reward at episode 872: 200.0
# Total reward at episode 873: 200.0
# Total reward at episode 874: 200.0
# Total reward at episode 875: 200.0
# Total reward at episode 876: 200.0
# Total reward at episode 877: 200.0
# Total reward at episode 878: 200.0
# Total reward at episode 879: 200.0
# Total reward at episode 880: 200.0
# Total reward at episode 881: 200.0
# Total reward at episode 882: 200.0
# Total reward at episode 883: 200.0
# Total reward at episode 884: 200.0
# Total reward at episode 885: 200.0
# Total reward at episode 886: 200.0
# Total reward at episode 887: 200.0
# Total reward at episode 888: 200.0
# Total reward at episode 889: 200.0
# Total reward at episode 890: 200.0
# Total reward at episode 891: 200.0
# Total reward at episode 892: 200.0
# Total reward at episode 893: 200.0
# Total reward at episode 894: 200.0
# Total reward at episode 895: 200.0
# Total reward at episode 896: 200.0
# Total reward at episode 897: 200.0
# Total reward at episode 898: 200.0
# Total reward at episode 899: 200.0
# Total reward at episode 900: 200.0
# Total reward at episode 901: 200.0
# Total reward at episode 902: 200.0
# Total reward at episode 903: 200.0
# Total reward at episode 904: 200.0
# Total reward at episode 905: 200.0
# Total reward at episode 906: 200.0
# Total reward at episode 907: 200.0
# Total reward at episode 908: 200.0
# Total reward at episode 909: 200.0
# Total reward at episode 910: 200.0
# Total reward at episode 911: 200.0
# Total reward at episode 912: 200.0
# Total reward at episode 913: 200.0
# Total reward at episode 914: 200.0
# Total reward at episode 915: 200.0
# Total reward at episode 916: 200.0
# Total reward at episode 917: 200.0
# Total reward at episode 918: 200.0
# Total reward at episode 919: 200.0
# Total reward at episode 920: 200.0
# Total reward at episode 921: 200.0
# Total reward at episode 922: 200.0
# Total reward at episode 923: 200.0
# Total reward at episode 924: 200.0
# Total reward at episode 925: 200.0
# Total reward at episode 926: 200.0
# Total reward at episode 927: 200.0
# Total reward at episode 928: 200.0
# Total reward at episode 929: 200.0
# Total reward at episode 930: 200.0
# Total reward at episode 931: 200.0
# Total reward at episode 932: 200.0
# Total reward at episode 933: 200.0
# Total reward at episode 934: 200.0
# Total reward at episode 935: 200.0
# Total reward at episode 936: 200.0
# Total reward at episode 937: 200.0
# Total reward at episode 938: 200.0
# Total reward at episode 939: 200.0
# Total reward at episode 940: 200.0
# Total reward at episode 941: 200.0
# Total reward at episode 942: 200.0
# Total reward at episode 943: 200.0
# Total reward at episode 944: 200.0
# Total reward at episode 945: 200.0
# Total reward at episode 946: 200.0
# Total reward at episode 947: 200.0
# Total reward at episode 948: 200.0
# Total reward at episode 949: 200.0
# Total reward at episode 950: 200.0
# Total reward at episode 951: 200.0
# Total reward at episode 952: 200.0
# Total reward at episode 953: 200.0
# Total reward at episode 954: 200.0
# Total reward at episode 955: 200.0
# Total reward at episode 956: 200.0
# Total reward at episode 957: 200.0
# Total reward at episode 958: 200.0
# Total reward at episode 959: 200.0
# Total reward at episode 960: 200.0
# Total reward at episode 961: 200.0
# Total reward at episode 962: 200.0
# Total reward at episode 963: 200.0
# Total reward at episode 964: 200.0
# Total reward at episode 965: 200.0
# Total reward at episode 966: 200.0
# Total reward at episode 967: 200.0
# Total reward at episode 968: 200.0
# Total reward at episode 969: 200.0
# Total reward at episode 970: 200.0
# Total reward at episode 971: 200.0
# Total reward at episode 972: 200.0
# Total reward at episode 973: 200.0
# Total reward at episode 974: 200.0
# Total reward at episode 975: 200.0
# Total reward at episode 976: 200.0
# Total reward at episode 977: 200.0
# Total reward at episode 978: 200.0
# Total reward at episode 979: 200.0
# Total reward at episode 980: 200.0
# Total reward at episode 981: 200.0
# Total reward at episode 982: 200.0
# Total reward at episode 983: 200.0
# Total reward at episode 984: 200.0
# Total reward at episode 985: 200.0
# Total reward at episode 986: 200.0
# Total reward at episode 987: 200.0
# Total reward at episode 988: 200.0
# Total reward at episode 989: 200.0
# Total reward at episode 990: 200.0
# Total reward at episode 991: 200.0
# Total reward at episode 992: 200.0
# Total reward at episode 993: 200.0
# Total reward at episode 994: 200.0
# Total reward at episode 995: 200.0
# Total reward at episode 996: 200.0
# Total reward at episode 997: 200.0
# Total reward at episode 998: 200.0
# Total reward at episode 999: 200.0
# Total reward at episode 1000: 200.0
# Average reward over 1000 episodes: 128
# Reward of 200 appeared 441 times in 1000 episodes

# %% [markdown]
# ### MountainCar
#
# Now apply the things you've learned to the MountainCar problem. Please note that the observable space differs from the previous problem. Thus, before you start training, you need to learn more about thethis new environment.
#
# Here is some code to help you get started..

# %%
# # Create the desired environment
# env = gym.make("MountainCar-v0")

# # Wrap the environment, to make sure we get to see a fancy video
# env = video_env(env)

# # Before you can use a Gym environment, it needs to be reset.
# state = env.reset()

# # Perform random actions untill we drop the stick. Just as an example.
# done = False
# while not done:
   
#     # Explore and take actions
#     pass

#     # Remove the line below when you have created an implementation you want to test.
#     done = True

# # Show the results!
# env.close()
# show_video()
